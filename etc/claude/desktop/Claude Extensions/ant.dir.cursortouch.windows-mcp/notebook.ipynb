# %%
from src.desktop.service import Desktop

desktop=Desktop()
desktop.execute_command('ollama list')
# Out:
# ('NAME                   ID              SIZE      MODIFIED    \ngemma3:4b              a2af6cc3eb7f    3.3 GB    9 days ago     \nqwen3-vl:235b-cloud    7fc468f95411    -         9 days ago     \ngpt-oss:120b-cloud     569662207105    -         4 weeks ago    \n',
#  0)
